# %%
from PIL import Image as im
import numpy as np
import helper

# %%
img = helper.read_8bit_img_from_raw_data("WashigntonDC_subtract.raw", 512, 512);
print("[{}, {}]".format(img.min(), img.max()))
im.fromarray(img)
# Out:
# [0, 255]
# <PIL.Image.Image image mode=L size=512x512>

# %%
img = helper.read_8bit_img_from_raw_data("lena_negative.raw", 512, 512);
print("[{}, {}]".format(img.min(), img.max()))
im.fromarray(img)
# Out:
# [11, 235]
# <PIL.Image.Image image mode=L size=512x512>

# %%
img = helper.read_8bit_img_from_raw_data("lena_translation.raw", 512, 512);
print("[{}, {}]".format(img.min(), img.max()))
im.fromarray(img)
# Out:
# [0, 244]
# <PIL.Image.Image image mode=L size=512x512>

# %%
img = helper.read_8bit_img_from_raw_data("pollen_intensity_slicing.raw", 500, 500);
print("[{}, {}]".format(img.min(), img.max()))
im.fromarray(img)
# Out:
# [125, 200]
# <PIL.Image.Image image mode=L size=500x500>
